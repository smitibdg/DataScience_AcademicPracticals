# %%
import nltk

# %%
pip install nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
from nltk.corpus import brown

# %%
from nltk.book import*
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# Q.1. Try using the python interpreter as a calculator, and expressions like 12 / (4 + 1).

# %%
120+35*17
# Out:
# 715

# %% [markdown]
# Q.2. Given an Alphabet of 26 letters, there are 26 to the power 10, or 26**10, ten-letter strings we can form. That works out to 141167095653376.
#
# How many hundred letter stings are possible?

# %%
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# Q.3. The Python multiplication Operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?

# %%
['Monty', 'Python'] * 20
# Out:
# ['Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python']

# %%
3 * sent1
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.']

# %% [markdown]
# Q.4. How many words are there in text2? How many distinct words are there?

# %%
len(text2)
# Out:
# 141576

# %%
len(set(text2))
# Out:
# 6833

# %% [markdown]
# Q.5. Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexical diverse?

# %%
def lexical_diversity(text):
  return len(text) / len(set(text))

# %%
lexical_diversity(text6)
# Humor Fiction
# Out:
# 7.833333333333333

# %%
lexical_diversity(text2)
# Out:
# 20.719449729255086

# %% [markdown]
# So we can conclude that humor fiction is more lexical diverse.
# Q.6. Produce a dispersion plot of the four main protagonists in sense and sensibility :Elinor, Marianne, Edward and willoughby. What can you obverse about the different roles played by the males and females in the novel? Can you identify the couples.

# %%
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# Every role has been given a good amout of space throughout the novel.
#
# Also we get to know that the major part of the novel has been taken by Elinor followed by Marianne then comes Edward and finally Willoughby. Also we can conclude that females have a greater role than the males in the novel.
#
# The couple were Edward and Elinor.
#
# Q.7. Find the collocations in text5.

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# Q.8. Consider the following the Python Expressions:len(set(text4)). State the purpose of this expression. Describe the two steps involved in performing this computation.
#
# Ans. This expression is used to find the totalnumber of distinct words in text4.
#
# set() is used to find the distinct words.
# len() is used to find the total number of words.
#
# Q.9.a.  Define a string and assign it to a variable, e.g., my_string = 'My String' (but put something more interesting in the string). Print the contents of this variable in two ways, first by simply typing the variable name and pressing enter, then by using the print statement.

# %%
king = "Waiting for the Queen(Smiti)"
king
# Out:
# 'Waiting for the Queen(Smiti)'

# %%
print(king)
# Out:
# Waiting for the Queen(Smiti)

# %% [markdown]
# Q.9.b. Try adding the string to itself using my_string + my_string, or multiplying it by a number, e.g., my_string * 3. Notice that the strings are joined together without any spaces. How could you fix this.

# %%
king + king
# Out:
# 'Waiting for the Queen(Smiti)Waiting for the Queen(Smiti)'

# %%
king * 3
# Out:
# 'Waiting for the Queen(Smiti)Waiting for the Queen(Smiti)Waiting for the Queen(Smiti)'

# %% [markdown]
# Q.10.a. Define a variable my_sent to be a list of words, using the syntax my_sent= ["My", "sent"] . (but with your own words , or a favourite saying)
#
# Use "join(my_sent) to convert this into a string.

# %%
proverb = ["Better","Late","Than","Never"]

# %%
''.join(proverb)
# Out:
# 'BetterLateThanNever'

# %% [markdown]
# Q.10.b. Use Split() to split the string back intp the list from u had to start with

# %%
'Better Late Than Never'.split()
# Out:
# ['Better', 'Late', 'Than', 'Never']
